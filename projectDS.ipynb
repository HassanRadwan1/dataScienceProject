# %% [markdown]
# ## intro

# %%
# import packages to use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # load first file (User_Information.csv) , and display information

# %%
# Load csv file named tmdb-movies.csv' into data frame DF1
df1 = pd.read_csv('User_Information.csv')
# dimensions of DF1
print("Dimensions of DF1: ", df1.shape)
# print Information of DF1
print("\nInformation about DF1: ",df1.info())
# First 5 rows of DF1
print("\nFirst 5 rows (head) of DF1: \n")
df1.head()
# Out:
# Dimensions of DF1:  (4137, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4137 entries, 0 to 4136
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                4137 non-null   object
#  1   Age               4135 non-null   float64
#  2   Gender            4086 non-null   object
#  3   Country           4134 non-null   object
#  4   Sign Up Date      4134 non-null   object
#  5   Membership Level  4137 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 194.1+ KB
#
# Information about DF1:  None
#
# First 5 rows (head) of DF1:
#       ID   Age  Gender  Country Sign Up Date Membership Level
# 0  U1327  67.0  Female   Canada   10/30/2019             Free
# 1   U301  37.0    Male  Germany    10/5/2017             Gold
# 2  U1647  65.0    Male      USA    7/20/2016             Free
# 3  U2307  35.0  Female  Germany    7/20/2017           Silver
# 4  U2092  47.0  Female    India   11/24/2018             Gold

# %% [markdown]
# # load second file (User_Activity.csv) , and display information

# %%
# Load csv file named tmdb-movies.csv' into data frame DF2
df2 = pd.read_csv('User_Activity.csv')
# dimensions of DF2
print("Dimensions of DF2: ", df2.shape)
# print Information of DF2
print("\nInformation about DF2: ",df2.info())
# First 5 rows of DF2
print("\nFirst 5 rows (head) of DF2: \n")
df2.head()
# Out:
# Dimensions of DF2:  (4319, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4319 entries, 0 to 4318
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                4319 non-null   object
#  1   Last Login        4315 non-null   object
#  2   Total Purchases   4294 non-null   float64
#  3   Total Time Spent  4295 non-null   float64
#  4   Number of Posts   4317 non-null   float64
#  5   Likes Given       4317 non-null   float64
#  6   Payment Method    4317 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 236.3+ KB
#
# Information about DF2:  None
#
# First 5 rows (head) of DF2:
#       ID  Last Login  Total Purchases  Total Time Spent  Number of Posts  \
# 0  U1969   5/22/2023             30.0            443.00            441.0
# 1   U626  11/27/2023             47.0            341.51            326.0
# 2   U269   7/26/2023             33.0             19.96            339.0
# 3  U1678  11/29/2023             46.0            319.60            492.0
# 4  U1329    6/4/2023             35.0            441.98            919.0
#
#    Likes Given Payment Method
# 0       4053.0         PayPal
# 1       4122.0    Credit Card
# 2       1837.0         PayPal
# 3         67.0    Credit Card
# 4       4632.0  Bank Transfer

# %% [markdown]
# # merge:
# -  Standardize Column Names first
# - we have common column [id] in both datasets , so we are going to use inner join on [id] column

# %%
# Standardize Column Names
df1.columns = df1.columns.str.lower().str.replace(' ', '_')
df2.columns = df2.columns.str.lower().str.replace(' ', '_')
# update columns names
df1.to_csv('User_Information.csv', index=False)
df2.to_csv('User_Activity.csv', index=False)

# Merge (Inner join)
innerjoin=pd.merge(df1,df2,on='id')
# Save file after inner join
innerjoin.to_csv('innerjoin.csv',index=False)
print("File was saved")
# Out:
# File was saved
# Dimensions of innermerge:  (4113, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4113 entries, 0 to 4112
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                4113 non-null   object
#  1   age               4111 non-null   float64
#  2   gender            4076 non-null   object
#  3   country           4110 non-null   object
#  4   sign_up_date      4110 non-null   object
#  5   membership_level  4113 non-null   object
#  6   last_login        4109 non-null   object
#  7   total_purchases   4088 non-null   float64
#  8   total_time_spent  4089 non-null   float64
#  9   number_of_posts   4111 non-null   float64
#  10  likes_given       4111 non-null   float64
#  11  payment_method    4111 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 385.7+ KB
#
# Information about inner:  None
#
# First 5 rows (head) of innerjoin:
#       id   age  gender  country sign_up_date membership_level last_login  \
# 0  U1327  67.0  Female   Canada   10/30/2019             Free  3/11/2023
# 1   U301  37.0    Male  Germany    10/5/2017             Gold   3/5/2023
# 2  U1647  65.0    Male      USA    7/20/2016             Free   1/6/2023
# 3  U2092  47.0  Female    India   11/24/2018             Gold   7/1/2023
# 4   U557  61.0  Female  Germany    6/19/2021             Gold  6/15/2023
#
#    total_purchases  total_time_spent  number_of_posts  likes_given  \
# 0             29.0            270.38            654.0       3115.0
# 1             26.0            143.35            301.0        686.0
# 2             11.0            259.84             89.0       4346.0
# 3             24.0            148.61            299.0       3474.0
# 4             40.0            196.67            647.0       3713.0
#
#   payment_method
# 0         Crypto
# 1         Crypto
# 2         Crypto
# 3         Crypto
# 4    Credit Card

# %% [markdown]
# # Explore Data

# %%
# dimensions after merge
print("Dimensions of innermerge: ", innerjoin.shape)
# print Information of DF
print("\nInformation about inner: ",innerjoin.info())
# First fifth rows of DF
print("\nFirst 5 rows (head) of innerjoin: \n")
innerjoin.head()
# Out:
# Dimensions of innermerge:  (4113, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4113 entries, 0 to 4112
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                4113 non-null   object
#  1   age               4111 non-null   float64
#  2   gender            4076 non-null   object
#  3   country           4110 non-null   object
#  4   sign_up_date      4110 non-null   object
#  5   membership_level  4113 non-null   object
#  6   last_login        4109 non-null   object
#  7   total_purchases   4088 non-null   float64
#  8   total_time_spent  4089 non-null   float64
#  9   number_of_posts   4111 non-null   float64
#  10  likes_given       4111 non-null   float64
#  11  payment_method    4111 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 385.7+ KB
#
# Information about inner:  None
#
# First 5 rows (head) of innerjoin:
#       id   age  gender  country sign_up_date membership_level last_login  \
# 0  U1327  67.0  Female   Canada   10/30/2019             Free  3/11/2023
# 1   U301  37.0    Male  Germany    10/5/2017             Gold   3/5/2023
# 2  U1647  65.0    Male      USA    7/20/2016             Free   1/6/2023
# 3  U2092  47.0  Female    India   11/24/2018             Gold   7/1/2023
# 4   U557  61.0  Female  Germany    6/19/2021             Gold  6/15/2023
#
#    total_purchases  total_time_spent  number_of_posts  likes_given  \
# 0             29.0            270.38            654.0       3115.0
# 1             26.0            143.35            301.0        686.0
# 2             11.0            259.84             89.0       4346.0
# 3             24.0            148.61            299.0       3474.0
# 4             40.0            196.67            647.0       3713.0
#
#   payment_method
# 0         Crypto
# 1         Crypto
# 2         Crypto
# 3         Crypto
# 4    Credit Card

# %%
innerjoin.isnull().sum()
# Out:
# id                   0
# age                  2
# gender              37
# country              3
# sign_up_date         3
# membership_level     0
# last_login           4
# total_purchases     25
# total_time_spent    24
# number_of_posts      2
# likes_given          2
# payment_method       2
# dtype: int64

# %%
sns.heatmap(innerjoin.isnull())
# Out:
# <Axes: >

# %%
innerjoin.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Data cleaning
# - 1-drop rows with non value (axis=0)
# - 1-Remove duplication in the rows (check and process if exist)
# - 2-Remove rows contains noisy data (Some movies has 'zero' budget or revenue. So,
# - we need to discard it)
# - 3-Check NN values and modify it with a value (zero or mean or median or stay as it is
# - according to the data)

# %%
# drop non values , and update after droping
innerjoin=innerjoin.dropna()
print(innerjoin.shape)
innerjoin.info()
# Out:
# (4009, 12)
# <class 'pandas.core.frame.DataFrame'>
# Index: 4009 entries, 0 to 4112
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                4009 non-null   object
#  1   age               4009 non-null   float64
#  2   gender            4009 non-null   object
#  3   country           4009 non-null   object
#  4   sign_up_date      4009 non-null   object
#  5   membership_level  4009 non-null   object
#  6   last_login        4009 non-null   object
#  7   total_purchases   4009 non-null   float64
#  8   total_time_spent  4009 non-null   float64
#  9   number_of_posts   4009 non-null   float64
#  10  likes_given       4009 non-null   float64
#  11  payment_method    4009 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 407.2+ KB
